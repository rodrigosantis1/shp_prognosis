# %% [markdown]
# # Survival Analysis
#
#
# #### TODO
#
# - Implement different metric
# - Implement simulation in a different script

# %%
random_state = 20
min_operating_time = 30
figsize = (8,6)
features = 'hos_features' # 'hos_features' # tsfresh_features_sel

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.style.use(['science','ieee'])

from sklearn.model_selection import train_test_split
from sksurv.nonparametric import kaplan_meier_estimator
from sksurv.ensemble import RandomSurvivalForest

from sksurv.linear_model import CoxnetSurvivalAnalysis
from sksurv.ensemble import GradientBoostingSurvivalAnalysis
import os
os.environ["PATH"] += os.pathsep + '/Library/TeX/texbin'

# %% [markdown]
# ### Data retrieval

# %%
df_l = []

for generator in range(1,5):

    df = pd.read_csv(f'../data/prepared/ap{generator}_data.csv')

    df['time'] = df.groupby('Run').cumcount(ascending=True)
    df['generator'] = generator

    df.rename(columns={'Vazão Turbinado':'Vazão Turbinada'}, inplace=True)

    df = df.drop(columns=['Gerador - Energia Consumida', 'Gerador - Energia Ativa Fornecida',
       'Gerador - Energia Reativa Fornecida',  'Gerador - Horímetro Elétrico', 'Gerador - Horímetro Mecânico'])


    df_l.append(df)

df = pd.concat(df_l)

df['id'] = df['generator'].astype(str) + '-' + df['Run'].astype(str)

df.head()
# Out:
#            E3TimeStamp  Gerador - Corrente Média  Gerador - Corrente R  \
# 0  2018-07-01 00:00:00                     228.0                 227.0
# 1  2018-07-01 00:05:00                     233.0                 233.0
# 2  2018-07-01 00:10:00                     235.0                 234.0
# 3  2018-07-01 00:15:00                     232.0                 227.0
# 4  2018-07-01 00:20:00                     235.0                 233.0
#
#    Gerador - Corrente S  Gerador - Corrente T  Gerador - Frequência  \
# 0                 230.0                 227.0             60.000000
# 1                 235.0                 232.0             59.990002
# 2                 237.0                 234.0             60.000000
# 3                 230.0                 231.0             60.000000
# 4                 237.0                 234.0             60.009998
#
#    Gerador - Potência Ativa Média  Gerador - Potência Reativa Média  \
# 0                          5660.0                             126.0
# 1                          5708.0                             123.0
# 2                          5838.0                             112.0
# 3                          5636.0                             132.0
# 4                          5794.0                             130.0
#
#    Gerador - Tensão RN  Gerador - Tensão SN  ...  Vazão Turbinada  \
# 0                 8.27                 8.25  ...              0.0
# 1                 8.26                 8.24  ...              0.0
# 2                 8.27                 8.25  ...              0.0
# 3                 8.26                 8.24  ...              0.0
# 4                 8.27                 8.25  ...              0.0
#
#    RegV - Rotor  Gerador - Potência Aparente Média       EVI  isMissing  \
# 0     90.300003                             5662.0  0.690869        0.0
# 1     91.599998                             5709.0  0.873441        0.0
# 2     91.300003                             5839.0  0.705691        0.0
# 3     89.199997                             5638.0  0.691231        0.0
# 4     91.199997                             5795.0  0.817129        0.0
#
#    Breakdown  Run  time  generator   id
# 0      False    0     0          1  1-0
# 1      False    0     1          1  1-0
# 2      False    0     2          1  1-0
# 3      False    0     3          1  1-0
# 4      False    0     4          1  1-0
#
# [5 rows x 55 columns]

# %% [markdown]
# #### Group data per generator-run

# %%
# Get data fror
data = df.dropna().groupby('id').agg({
    'Run':'median',
    'Breakdown':'median',
    'time':'max',
})

data = data[data['time'] > min_operating_time] # Select only runs with time 

data['Breakdown'] = data['Breakdown'].astype(bool)

data.head()
# Out:
#        Run  Breakdown  time
# id
# 1-0      0      False   669
# 1-1      1      False  1409
# 1-10    10      False   170
# 1-100  100      False    90
# 1-101  101      False    31

# %%
data['generator'] = data.reset_index()['id'].str.split('-', expand=True)[0].astype(int).values

plt.figure(figsize=figsize)

for generator in range(1,5):

    mask = data["generator"] == generator

    time_treatment, survival_prob_treatment = kaplan_meier_estimator(
        data.loc[data.generator == generator, "Breakdown"], 
        data.loc[data.generator == generator, "time"])

    plt.step(time_treatment, survival_prob_treatment, where="post",
                label=f"generator={generator}")

time_treatment, survival_prob_treatment = kaplan_meier_estimator(
    data['Breakdown'], data['time'])

plt.step(time_treatment, survival_prob_treatment, where="post",
            label="all", c='k', ls=":")

plt.ylabel("est. probability of survival $\hat{S}(t)$")
plt.xlabel("time $t$")
plt.legend(loc="best")

# %% [markdown]
# #### Load features

# %%
if features == 'hos_features':
    df_feature = pd.read_csv('../data/preprocessed/hos_features_rev2.zip', compression='zip', index_col=0, skiprows=[1,2])
else:
    df_feature = pd.read_csv('../data/preprocessed/tsfresh_features_sel.zip', index_col=0, compression='zip')

df_feature = df_feature.reindex(data.index)
df_feature.head()
# Out:
#        Gerador - Corrente Média  Gerador - Corrente Média.1  \
# id
# 1-0                  198.130000                 1162.316263
# 1-1                  204.240000                 1744.265051
# 1-10                   0.000000                    0.000000
# 1-100                114.989011                 2183.966545
# 1-101                103.156250                  674.652218
#
#        Gerador - Corrente Média.2  Gerador - Corrente Média.3  \
# id
# 1-0                     -0.165168                   -1.942680
# 1-1                     -1.667459                    1.492756
# 1-10                     0.000000                    0.000000
# 1-100                    0.345073                    0.773921
# 1-101                   -2.294283                    7.200869
#
#        Gerador - Corrente R  Gerador - Corrente R.1  Gerador - Corrente R.2  \
# id
# 1-0              197.370000             1165.225354               -0.162214
# 1-1              204.100000             1741.242424               -1.668417
# 1-10               0.000000                0.000000                0.000000
# 1-100            114.384615             2186.728205                0.356646
# 1-101            102.312500              673.576613               -2.245752
#
#        Gerador - Corrente R.3  Gerador - Corrente S  Gerador - Corrente S.1  \
# id
# 1-0                 -1.943480             200.22000             1160.375354
# 1-1                  1.494138             206.21000             1742.955455
# 1-10                 0.000000               0.00000                0.000000
# 1-100                0.747054             116.32967             2207.112332
# 1-101                6.936405             104.40625              689.926411
#
#        ...  Vazão Turbinada.2  Vazão Turbinada.3  RegV - Rotor  \
# id     ...
# 1-0    ...           0.000000           0.000000     80.809000
# 1-1    ...           0.000000           0.000000     89.897000
# 1-10   ...           0.000000           0.000000    100.000000
# 1-100  ...           0.549519           0.675490     39.893406
# 1-101  ...          -2.190149           5.351828     31.803125
#
#        RegV - Rotor.1  RegV - Rotor.2  RegV - Rotor.3  \
# id
# 1-0        111.877193       -0.157814       -1.955143
# 1-1        249.226954       -1.759966        2.237056
# 1-10         0.000000        0.000000        0.000000
# 1-100      444.563518        1.528023        1.536071
# 1-101      348.861608        3.221776       10.463282
#
#        Gerador - Potência Aparente Média  Gerador - Potência Aparente Média.1  \
# id
# 1-0                           4926.46000                         7.290654e+05
# 1-1                           5157.47000                         1.090790e+06
# 1-10                             0.00000                         0.000000e+00
# 1-100                         2840.32967                         1.362226e+06
# 1-101                         2541.59375                         4.104075e+05
#
#        Gerador - Potência Aparente Média.2  \
# id
# 1-0                              -0.165904
# 1-1                              -1.682809
# 1-10                              0.000000
# 1-100                             0.386335
# 1-101                            -2.277130
#
#        Gerador - Potência Aparente Média.3
# id
# 1-0                              -1.948309
# 1-1                               1.552395
# 1-10                              0.000000
# 1-100                             0.733302
# 1-101                             7.155181
#
# [5 rows x 188 columns]

# %%
y = np.zeros(len(data), dtype={'names': ('cens', 'time'), 'formats': ('?', '<f8')})
y['cens'] = data['Breakdown'].tolist()
y['time'] = data['time'].tolist()

X = df_feature.values

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=random_state)

# %%
models = [

    ('CoxNet', CoxnetSurvivalAnalysis()),

    ('RSF', RandomSurvivalForest(n_estimators=100,
                            min_samples_split=10,
                            min_samples_leaf=15,
                            max_features="sqrt",
                            n_jobs=-1,
                            random_state=random_state)),

    ('GBSA', GradientBoostingSurvivalAnalysis(n_estimators=100, learning_rate=1.0, random_state=random_state)),
]

for model_name, model in models:

    model.fit(X_train, y_train)

    print(model_name)
    print(model.score(X_test, y_test).round(3))
# Out:
# CoxNet
# 0.68
# RSF
# 0.721
# GBSA
# 0.759

# %% [markdown]
# ### Model convergence analysis

# %%
results = {}

for min_samples in [5,10,25,50]:
    scores = []
    
    rsf = RandomSurvivalForest(n_estimators=1,
                        #min_samples_split=10,
                        min_samples_leaf=min_samples,
                        max_features="sqrt",
                        n_jobs=-1,
                        warm_start=True,
                        random_state=random_state)
        
    for n in range(1,500):
        rsf.n_estimators += 1
        rsf.fit(X_train, y_train)
        scores.append(rsf.score(X_test, y_test))
    results.update({min_samples:scores})

# %%
plt.figure(figsize=figsize)
    
for key, value in results.items():

    plt.step(range(1,500), 1-np.array(value), label="min_samples_leaf={}".format(key), ls='-', lw=0.8)
    plt.xlabel('Number of trees')
    plt.ylabel('Error rate')
    plt.legend()

# %% [markdown]
# ### Survival and Hazard function

# %%
rsf = RandomSurvivalForest(n_estimators=100,
                            min_samples_split=10,
                            min_samples_leaf=15,
                            max_features="sqrt",
                            n_jobs=-1,
                            random_state=random_state)

rsf.fit(X_train, y_train)
# Out:
# RandomSurvivalForest(max_features='sqrt', min_samples_leaf=15,
#                      min_samples_split=10, n_jobs=-1, random_state=20)

# %%
surv = rsf.predict_survival_function(X_test, return_array=True)

plt.figure(figsize=figsize)
for i, s in enumerate(surv):
    plt.step(rsf.event_times_, s, where="post", label=str(i))
plt.ylabel("Survival probability")
plt.xlabel("Time in days")
# Out:
# Text(0.5, 0, 'Time in days')

# %%
surv = rsf.predict_cumulative_hazard_function(X_test, return_array=True)

plt.figure(figsize=figsize)
for i, s in enumerate(surv):
    plt.step(rsf.event_times_, s, where="post", label=str(i))
plt.ylabel("Cumulative hazard")
plt.xlabel("Time in days")
# Out:
# Text(0.5, 0, 'Time in days')

# %% [markdown]
# ### Feature importance

# %%
import eli5
from eli5.sklearn import PermutationImportance

feature_names = df_feature.columns.tolist()
perm = PermutationImportance(rsf, n_iter=15, random_state=random_state)
perm.fit(X_test, y_test)
eli5.show_weights(perm, feature_names=feature_names)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0285
#
#                     &plusmn; 0.0346
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 RegV - Velocidade.3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.19%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0281
#
#                     &plusmn; 0.0156
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 UHCT - Temperatua Óleo.2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0180
#
#                     &plusmn; 0.0189
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gerador - Temperatura Mancal LA Casquilho 02.2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.28%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0149
#
#                     &plusmn; 0.0241
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Turbina - Temperatura Gaxeteiro Jusante
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.07%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0120
#
#                     &plusmn; 0.0120
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 RegT - Tensão Excitação.1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0116
#
#                     &plusmn; 0.0223
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Turbina - Temperatura MC Bucha Radial
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.32%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0116
#
#                     &plusmn; 0.0064
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Caixa Espiral - Pressão.3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.44%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0114
#
#                     &plusmn; 0.0083
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gerador - Corrente T.1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.70%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0110
#
#                     &plusmn; 0.0048
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gerador - Corrente S.1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 89.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0107
#
#                     &plusmn; 0.0055
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 RegV - Distribuiidor.1
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.21%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0103
#
#                     &plusmn; 0.0092
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gerador - Temperatura Mancal LA Casquilho 01
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 90.86%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0093
#
#                     &plusmn; 0.0117
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gerador - Temperatura Mancal LNA Casquilho 01.2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0091
#
#                     &plusmn; 0.0127
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Vibração Mancal Combinado Lado Acoplado.3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.40%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0085
#
#                     &plusmn; 0.0157
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gerador - Temperatura Mancal LNA Casquilho 02.3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.68%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0081
#
#                     &plusmn; 0.0141
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gerador - Tensão RN
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.82%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0079
#
#                     &plusmn; 0.0096
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 UHCT - Temperatua Óleo.3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 91.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0078
#
#                     &plusmn; 0.0127
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; tex
