# %% [markdown]
# # Survival Analysis
#
#
# #### TODO
#
# - Implement different metric
# - Implement simulation in a different script

# %%
random_state = 20
min_operating_time = 30
figsize = (8,6)
features = 'tsfresh_features_sel' # 'hos_features' # tsfresh_features_sel

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.style.use(['science','ieee'])

from sklearn.model_selection import train_test_split
from sksurv.nonparametric import kaplan_meier_estimator
from sksurv.ensemble import RandomSurvivalForest

from sksurv.linear_model import CoxnetSurvivalAnalysis
from sksurv.ensemble import GradientBoostingSurvivalAnalysis
import os
os.environ["PATH"] += os.pathsep + '/Library/TeX/texbin'

# %% [markdown]
# ### Data retrieval

# %%
df_l = []

for generator in range(1,5):

    df = pd.read_csv(f'../data/prepared/ap{generator}_data.csv')

    df['time'] = df.groupby('Run').cumcount(ascending=True)
    df['generator'] = generator

    df.rename(columns={'Vazão Turbinado':'Vazão Turbinada'}, inplace=True)

    df = df.drop(columns=['Gerador - Energia Consumida', 'Gerador - Energia Ativa Fornecida',
       'Gerador - Energia Reativa Fornecida',  'Gerador - Horímetro Elétrico', 'Gerador - Horímetro Mecânico'])


    df_l.append(df)

df = pd.concat(df_l)

df['id'] = df['generator'].astype(str) + '-' + df['Run'].astype(str)

df.head()
# Out:
#            E3TimeStamp  Gerador - Corrente Média  Gerador - Corrente R  \
# 0  2018-07-01 00:00:00                     228.0                 227.0
# 1  2018-07-01 00:05:00                     233.0                 233.0
# 2  2018-07-01 00:10:00                     235.0                 234.0
# 3  2018-07-01 00:15:00                     232.0                 227.0
# 4  2018-07-01 00:20:00                     235.0                 233.0
#
#    Gerador - Corrente S  Gerador - Corrente T  Gerador - Frequência  \
# 0                 230.0                 227.0             60.000000
# 1                 235.0                 232.0             59.990002
# 2                 237.0                 234.0             60.000000
# 3                 230.0                 231.0             60.000000
# 4                 237.0                 234.0             60.009998
#
#    Gerador - Potência Ativa Média  Gerador - Potência Reativa Média  \
# 0                          5660.0                             126.0
# 1                          5708.0                             123.0
# 2                          5838.0                             112.0
# 3                          5636.0                             132.0
# 4                          5794.0                             130.0
#
#    Gerador - Tensão RN  Gerador - Tensão SN  ...  Vazão Turbinada  \
# 0                 8.27                 8.25  ...              0.0
# 1                 8.26                 8.24  ...              0.0
# 2                 8.27                 8.25  ...              0.0
# 3                 8.26                 8.24  ...              0.0
# 4                 8.27                 8.25  ...              0.0
#
#    RegV - Rotor  Gerador - Potência Aparente Média       EVI  isMissing  \
# 0     90.300003                             5662.0  0.690869        0.0
# 1     91.599998                             5709.0  0.873441        0.0
# 2     91.300003                             5839.0  0.705691        0.0
# 3     89.199997                             5638.0  0.691231        0.0
# 4     91.199997                             5795.0  0.817129        0.0
#
#    Breakdown  Run  time  generator   id
# 0      False    0     0          1  1-0
# 1      False    0     1          1  1-0
# 2      False    0     2          1  1-0
# 3      False    0     3          1  1-0
# 4      False    0     4          1  1-0
#
# [5 rows x 55 columns]

# %% [markdown]
# #### Group data per generator-run

# %%
# Get data fror
data = df.dropna().groupby('id').agg({
    'Run':'median',
    'Breakdown':'median',
    'time':'max',
})

data = data[data['time'] > min_operating_time] # Select only runs with time 

data['Breakdown'] = data['Breakdown'].astype(bool)

data.head()
# Out:
#        Run  Breakdown  time
# id
# 1-0      0      False   669
# 1-1      1      False  1409
# 1-10    10      False   170
# 1-100  100      False    90
# 1-101  101      False    31

# %%
data['generator'] = data.reset_index()['id'].str.split('-', expand=True)[0].astype(int).values

plt.figure(figsize=figsize)

for generator in range(1,5):

    mask = data["generator"] == generator

    time_treatment, survival_prob_treatment = kaplan_meier_estimator(
        data.loc[data.generator == generator, "Breakdown"], 
        data.loc[data.generator == generator, "time"])

    plt.step(time_treatment, survival_prob_treatment, where="post",
                label=f"generator={generator}")

time_treatment, survival_prob_treatment = kaplan_meier_estimator(
    data['Breakdown'], data['time'])

plt.step(time_treatment, survival_prob_treatment, where="post",
            label="all", c='k', ls=":")

plt.ylabel("est. probability of survival $\hat{S}(t)$")
plt.xlabel("time $t$")
plt.legend(loc="best")

# %% [markdown]
# #### Load features

# %%
if features == 'hos_features':
    df_feature = pd.read_csv('../data/preprocessed/hos_features.zip', compression='zip', index_col=0, skiprows=[1,2])
else:
    df_feature = pd.read_csv('../data/preprocessed/tsfresh_features_sel.zip', index_col=0, compression='zip')
    df_feature = df_feature.loc[:, ~df_feature.columns.str.contains('length|sum|count')]

df_feature = df_feature.reindex(data.index)
df_feature.head()
# Out:
#        Gerador - Temperatura Mancal LA Casquilho 02__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)  \
# id
# 1-0                                            30.093585
# 1-1                                            11.508219
# 1-10                                           26.250341
# 1-100                                          16.561928
# 1-101                                          12.102471
#
#        Gerador - Temperatura Mancal LA Casquilho 01__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)  \
# id
# 1-0                                            27.864464
# 1-1                                             8.566762
# 1-10                                           25.792058
# 1-100                                          14.103825
# 1-101                                          10.756764
#
#        Turbina - Temperatura MC Sapatas Axiais Contra Escora 02__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)  \
# id
# 1-0                                            23.207909
# 1-1                                             7.276333
# 1-10                                           19.487104
# 1-100                                           9.874475
# 1-101                                           9.285939
#
#        Gerador - Temperatura Mancal LNA Casquilho 01__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)  \
# id
# 1-0                                            27.307175
# 1-1                                            10.393492
# 1-10                                           24.350405
# 1-100                                          15.446134
# 1-101                                          11.632461
#
#        Turbina - Temperatura MC Sapatas Axiais Contra Escora 01__fft_coefficient__attr_"abs"__coeff_1  \
# id
# 1-0                                           103.078869
# 1-1                                           302.062288
# 1-10                                          192.602952
# 1-100                                         272.702857
# 1-101                                         113.854025
#
#        Turbina - Temperatura MC Bucha Radial__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)  \
# id
# 1-0                                            19.505125
# 1-1                                             7.881435
# 1-10                                           15.957657
# 1-100                                          12.306315
# 1-101                                          10.758820
#
#        Gerador - Temperatura Mancal LNA Casquilho 02__cwt_coefficients__coeff_1__w_2__widths_(2, 5, 10, 20)  \
# id
# 1-0                                            27.307175
# 1-1                                            12.631112
# 1-10                                           24.380233
# 1-100                                          16.560694
# 1-101                                          12.949723
#
#        Turbina - Temperatura MC Sapatas Axiais Contra Escora 01__fft_aggregated__aggtype_"centroid"  \
# id
# 1-0                                             2.986338
# 1-1                                             4.096407
# 1-10                                            4.039576
# 1-100                                           2.355190
# 1-101                                           1.403934
#
#        Gerador - Temperatura Mancal LA Casquilho 02__cwt_coefficients__coeff_1__w_5__widths_(2, 5, 10, 20)  \
# id
# 1-0                                            20.634432
# 1-1                                             2.381411
# 1-10                                           22.295665
# 1-100                                           6.437958
# 1-101                                           4.126912
#
#        Turbina - Temperatura MC Sapatas Axiais Contra Escora 02__cwt_coefficients__coeff_1__w_5__widths_(2, 5, 10, 20)  \
# id
# 1-0                                            16.098176
# 1-1                                            -2.257982
# 1-10                                           16.027810
# 1-100                                           1.148414
# 1-101                                           0.894133
#
#        ...  \
# id     ...
# 1-0    ...
# 1-1    ...
# 1-10   ...
# 1-100  ...
# 1-101  ...
#
#        Turbina - Temperatura MC Sapatas Axiais Contra Escora 02__agg_linear_trend__attr_"intercept"__chunk_len_10__f_agg_"min"  \
# id
# 1-0                                            41.254545
# 1-1                                            25.527273
# 1-10                                           27.454545
# 1-100                                          29.418182
# 1-101                                          22.300000
#
#        Gerador - Corrente T__autocorrelation__lag_9  \
# id
# 1-0                                        0.733340
# 1-1                                        0.323934
# 1-10                                       0.125143
# 1-100                                      0.182214
# 1-101                                     -0.048108
#
#        Turbina - Temperatura Gaxeteiro Jusante__fft_coefficient__attr_"angle"__coeff_8  \
# id
# 1-0                                           -27.445048
# 1-1                                            72.272416
# 1-10                                            6.914135
# 1-100                                         -91.276677
# 1-101                                         135.000000
#
#        Vibração Mancal Combinado Lado Acoplado__approximate_entropy__m_2__r_0.3  \
# id
# 1-0                                             0.738320
# 1-1                                             0.555900
# 1-10                                            0.000000
# 1-100                                           0.348110
# 1-101                                           0.351268
#
#        Gerador - Potência Aparente Média__index_mass_quantile__q_0.6  \
# id
# 1-0                                             0.530000
# 1-1                                             0.640000
# 1-10                                            0.600000
# 1-100                                           0.692308
# 1-101                                           0.625000
#
#        Gerador - Corrente S__autocorrelation__lag_8  \
# id
# 1-0                                        0.766646
# 1-1                                        0.399109
# 1-10                                       0.146091
# 1-100                                      0.205254
# 1-101                                     -0.022961
#
#        Vibração Mancal Combinado Radial Vertical__approximate_entropy__m_2__r_0.9  \
# id
# 1-0                                             0.152351
# 1-1                                             0.175137
# 1-10                                            0.430108
# 1-100                                           0.164047
# 1-101                                           0.070399
#
#        Gerador - Tensão TN__change_quantiles__f_agg_"var"__isabs_False__qh_0.8__ql_0.4  \
# id
# 1-0                                             0.000138
# 1-1                                             0.000272
# 1-10                                            0.000000
# 1-100                                           0.000208
# 1-101                                           0.000141
#
#        Barra - Tensão__change_quantiles__f_agg_"var"__isabs_False__qh_0.4__ql_0.0  \
# id
# 1-0                                             0.000183
# 1-1                                             0.000549
# 1-10                                            0.001739
# 1-100                                           0.000824
# 1-101                                           0.000408
#
#        Gerador - Temperatura Mancal LA Casquilho 01__ratio_beyond_r_sigma__r_2.5
# id
# 1-0                                             0.000000
# 1-1                                             0.030000
# 1-10                                            0.020000
# 1-100                                           0.021978
# 1-101                                           0.031250
#
# [5 rows x 2511 columns]

# %%
y = np.zeros(len(data), dtype={'names': ('cens', 'time'), 'formats': ('?', '<f8')})
y['cens'] = data['Breakdown'].tolist()
y['time'] = data['time'].tolist()

X = df_feature.values

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=random_state)

# %%
models = [

    ('CoxNet', CoxnetSurvivalAnalysis()),

    ('RSF', RandomSurvivalForest(n_estimators=100,
                            min_samples_split=10,
                            min_samples_leaf=15,
                            max_features="sqrt",
                            n_jobs=-1,
                            random_state=random_state)),

    ('GBSA', GradientBoostingSurvivalAnalysis(n_estimators=100, learning_rate=1.0, random_state=random_state)),
]

for model_name, model in models:

    model.fit(X_train, y_train)

    print(model_name)
    print(model.score(X_test, y_test).round(3))
# Out:
# CoxNet
# 0.513
# RSF
# 0.814
# GBSA
# 0.741

# %% [markdown]
# ### Model convergence analysis

# %%
results = {}

for min_samples in [5,10,25,50]:
    scores = []
    
    rsf = RandomSurvivalForest(n_estimators=1,
                        #min_samples_split=10,
                        min_samples_leaf=min_samples,
                        max_features="sqrt",
                        n_jobs=-1,
                        warm_start=True,
                        random_state=random_state)
        
    for n in range(1,500):
        rsf.n_estimators += 1
        rsf.fit(X_train, y_train)
        scores.append(rsf.score(X_test, y_test))
    results.update({min_samples:scores})

# %%
plt.figure(figsize=figsize)
    
for key, value in results.items():

    plt.step(range(1,500), 1-np.array(value), label="min_samples_leaf={}".format(key), ls='-', lw=0.8)
    plt.xlabel('Number of trees')
    plt.ylabel('Error rate')
    plt.legend()

# %% [markdown]
# ### Survival and Hazard function

# %%
rsf = RandomSurvivalForest(n_estimators=100,
                            min_samples_split=10,
                            min_samples_leaf=15,
                            max_features="sqrt",
                            n_jobs=-1,
                            random_state=random_state)

rsf.fit(X_train, y_train)
# Out:
# RandomSurvivalForest(max_features='sqrt', min_samples_leaf=15,
#                      min_samples_split=10, n_jobs=-1, random_state=20)

# %%
surv = rsf.predict_survival_function(X_test[:20], return_array=True)

plt.figure(figsize=figsize)
for i, s in enumerate(surv):
    plt.step(rsf.event_times_, s, where="post", label=str(i))
plt.ylabel("Survival probability")
plt.xlabel("Time in days")
# Out:
# Text(0.5, 0, 'Time in days')

# %%
surv = rsf.predict_cumulative_hazard_function(X_test[:20], return_array=True)

plt.figure(figsize=figsize)
for i, s in enumerate(surv):
    plt.step(rsf.event_times_, s, where="post", label=str(i))
plt.ylabel("Cumulative hazard")
plt.xlabel("Time in days")
# Out:
# Text(0.5, 0, 'Time in days')

# %% [markdown]
# ### Feature importance

# %%
import eli5
from eli5.sklearn import PermutationImportance

feature_names = df_feature.columns.tolist()
perm = PermutationImportance(rsf, n_iter=15, random_state=random_state)
perm.fit(X_test, y_test)
eli5.show_weights(perm, feature_names=feature_names)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0122
#
#                     &plusmn; 0.0211
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Turbina - Temperatura MC Bucha Radial__cwt_coefficients__coeff_0__w_10__widths_(2, 5, 10, 20)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 81.12%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0112
#
#                     &plusmn; 0.0256
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Barra - Tensão__abs_energy
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 83.47%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0093
#
#                     &plusmn; 0.0147
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gerador - Temperatura Mancal LA Casquilho 01__cwt_coefficients__coeff_1__w_20__widths_(2, 5, 10, 20)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 84.69%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0083
#
#                     &plusmn; 0.0144
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 RegV - Velocidade__energy_ratio_by_chunks__num_segments_10__segment_focus_7
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 85.96%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0074
#
#                     &plusmn; 0.0125
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gerador - Tensão RN__cwt_coefficients__coeff_0__w_10__widths_(2, 5, 10, 20)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 86.48%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0070
#
#                     &plusmn; 0.0063
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gerador - Temperatura de Enrolamento fase T__agg_autocorrelation__f_agg_&quot;mean&quot;__maxlag_40
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.01%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0066
#
#                     &plusmn; 0.0204
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Turbina - Temperatura MC Bucha Radial__cwt_coefficients__coeff_5__w_10__widths_(2, 5, 10, 20)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.28%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0064
#
#                     &plusmn; 0.0098
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gerador - Tensão TS__cwt_coefficients__coeff_1__w_5__widths_(2, 5, 10, 20)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.28%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0064
#
#                     &plusmn; 0.0044
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gerador - Temperatura de Enrolamento fase S__cwt_coefficients__coeff_8__w_5__widths_(2, 5, 10, 20)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 87.28%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0064
#
#                     &plusmn; 0.0138
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gerador - Tensão ST__cwt_coefficients__coeff_0__w_10__widths_(2, 5, 10, 20)
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0052
#
#                     &plusmn; 0.0080
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Gerador - Potência Reativa Média__change_quantiles__f_agg_&quot;var&quot;__isabs_False__qh_0.2__ql_0.0
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0052
#
#                     &plusmn; 0.0044
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Vibração Mancal Combinado Radial Vertical__index_mass_quantile__q_0.3
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0052
#
#                     &plusmn; 0.0166
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Barra - Frequência__fft_coefficient__attr_&quot;real&quot;__coeff_0
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0052
#
#                     &plusmn; 0.0064
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 Turbina - Temperatura MC Bucha Radial__lempel_ziv_complexity__bins_2
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.95%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.0052
#
#                     &plusmn; 0.0088
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 UHLM Fluxostato 01__fft_coefficient__attr_&quot;abs&quot;__coeff_0
#             </td>
#         </tr>
#
#         <tr style="background-color: hsl(120, 100.00%, 88.
